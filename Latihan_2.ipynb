# %% [markdown]
# <a href="https://colab.research.google.com/github/Auryvilia/Komputer_Grafik/blob/main/Latihan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Dinda Putri Ramadani
#
# Nim: 8020220216
#
# Kelas: 07PT5
#
# Latihan dari elearning

# %%
! pip install Pillow
! pip install matplotlib
! pip install numpy
! pip install scipy

# %%
! wget https://cdn.pixabay.com/photo/2018/06/03/22/05/linda-flower-3451718_640.jpg
# Out:
# --2024-10-24 05:10:03--  https://cdn.pixabay.com/photo/2018/06/03/22/05/linda-flower-3451718_640.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.40.96, 172.64.147.160, 2606:4700:4400::6812:2860, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.40.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65657 (64K) [binary/octet-stream]
# Saving to: ‘linda-flower-3451718_640.jpg’
#
# linda-flower-345171 100%[===================>]  64.12K  --.-KB/s    in 0.02s
#
# 2024-10-24 05:10:03 (2.95 MB/s) - ‘linda-flower-3451718_640.jpg’ saved [65657/65657]

# %%
from pylab import *
from PIL import Image
flower_yellow = Image.open("linda-flower-3451718_640.jpg")
imshow(flower_yellow)
show()

# %%
from pylab import *
from PIL import Image
flower_yellow = Image.open("linda-flower-3451718_640.jpg")
imshow(flower_yellow)
show()

flower_yellow_gray = flower_yellow.convert("L")
gray()
imshow(flower_yellow_gray)
show()

# %%
from PIL import Image
from pylab import *

flower_yellow = Image.open("linda-flower-3451718_640.jpg")
print("Ukuran Asal :",flower_yellow)
out = flower_yellow.resize((200,200))
print("Ukuran resize :",out)
imshow(out)
# Out:
# Ukuran Asal : <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x791C0B3EAFB0>
# Ukuran resize : <PIL.Image.Image image mode=RGB size=200x200 at 0x791C0B3E9F60>

# %%
import os, sys, numpy
from PIL import Image

flower_yellow = Image.open("linda-flower-3451718_640.jpg")
# numpy.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(threshold = 100)
out = out

data = numpy.asarray(out)
print(data)
for i  in  data :
  print (i)
# Out:
# [[[196 208   4]
#   [179 196   5]
#   [138 161   6]
#   ...
#   [ 85 110   6]
#   [ 90 117   4]
#   [101 127   9]]
#
#  [[189 201   3]
#   [171 189   2]
#   [130 153   4]
#   ...
#   [ 75 100   0]
#   [ 80 105   0]
#   [ 89 113   1]]
#
#  [[180 193   3]
#   [162 180   3]
#   [122 144   4]
#   ...
#   [ 71  95   0]
#   [ 78 101   0]
#   [ 86 109   3]]
#
#  ...
#
#  [[  8   3   0]
#   [  7   2   0]
#   [  6   2   1]
#   ...
#   [169 101  18]
#   [152  81   9]
#   [165  95  13]]
#
#  [[  7   2   0]
#   [  6   2   0]
#   [  6   2   1]
#   ...
#   [109  45   4]
#   [124  60   7]
#   [127  67   5]]
#
#  [[  6   2   1]
#   [  6   2   1]
#   [  5   1   0]
#   ...
#   [131  69   7]
#   [143  75  10]
#   [139  70  10]]]
# [[196 208   4]
#  [179 196   5]
#  [138 161   6]
#  ...
#  [ 85 110   6]
#  [ 90 117   4]
#  [101 127   9]]
# [[189 201   3]
#  [171 189   2]
#  [130 153   4]
#  ...
#  [ 75 100   0]
#  [ 80 105   0]
#  [ 89 113   1]]
# [[180 193   3]
#  [162 180   3]
#  [122 144   4]
#  ...
# ...
