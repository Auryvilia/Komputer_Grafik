# %% [markdown]
# <a href="https://colab.research.google.com/github/Auryvilia/Komputer_Grafik/blob/main/Latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Dinda Putri Ramadani
#
# Nim: 8020220216
#
# Kelas: 07PT5
#
# Latihan 1 - Komputer Grafik

# %%
! pip install Pillow
! pip install matplotlib
! pip install numpy
! pip install scipy

# %%
! wget https://cdn.pixabay.com/photo/2022/12/01/04/43/girl-7628308_640.jpg
# Out:
# --2024-10-22 16:19:24--  https://cdn.pixabay.com/photo/2022/12/01/04/43/girl-7628308_640.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.40.96, 172.64.147.160, 2606:4700:4400::6812:2860, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.40.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46108 (45K) [image/jpeg]
# Saving to: ‘girl-7628308_640.jpg’
#
# girl-7628308_640.jp 100%[===================>]  45.03K  --.-KB/s    in 0.01s
#
# 2024-10-22 16:19:25 (3.15 MB/s) - ‘girl-7628308_640.jpg’ saved [46108/46108]

# %% [markdown]
# **LATIHAN**
# 1. Downloadlah sebuah image dan masukkan ke dalam google colab
# 2. Ubah warna image menjadi grayscale
# 3. Ubah ukuran image menjadi 200x200
# 4. Tampilkan mode warna dan ukuran image
# 5. Tampilkan nilai pixel dari image tersebut

# %%
from pylab import *
from PIL import Image
image_girl = Image.open("girl-7628308_640.jpg")
imshow(image_girl)
show()

# %%
from pylab import *
from PIL import Image

image_girl = Image.open("girl-7628308_640.jpg")
image_girl_gray = image_girl.convert("L")
gray()
imshow(image_girl_gray)
show()

# %%
from PIL import Image
from pylab import *
image_girl = Image.open("girl-7628308_640.jpg")
print("Ukuran Asal :",image_girl)
image_girl_resize = image_girl.resize((200,200))
print("Ukuran resize :",image_girl_resize)
imshow(image_girl_resize)
# Out:
# Ukuran Asal : <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x7F52ADEB4190>
# Ukuran resize : <PIL.Image.Image image mode=RGB size=200x200 at 0x7F52ADF911B0>

# %%
from pylab import *
from PIL import Image
image_girl = Image.open('girl-7628308_640.jpg')


image_gray = image_girl.convert('L')
print("Ukuran Asli : ", image_gray)
imshow(image_gray, 'gray')
show()



image_size200 = image_gray.resize((200,200))
print('Ukuran Resize :', image_size200)
imshow(image_size200, 'gray')
# Out:
# Ukuran Asli :  <PIL.Image.Image image mode=L size=640x427 at 0x7F52AD621510>
# Ukuran Resize : <PIL.Image.Image image mode=L size=200x200 at 0x7F52AD620730>

# %%
from pylab import *
from PIL import Image
image_girl =Image.open('girl-7628308_640.jpg')

image_gray = image_girl.convert('L')

image_size200 = image_gray.resize((200,200))
imshow(image_size200, 'gray')

print('Mode Warna : ', image_size200.mode)
print('Ukuran Gambar : ', image_size200.size)
# Out:
# Mode Warna :  L
# Ukuran Gambar :  (200, 200)

# %%
from pylab import *
from PIL import Image
image_girl =Image.open('girl-7628308_640.jpg')

image_gray = image_girl.convert('L')

image_size200 = image_gray.resize((200,200))
imshow(image_size200, 'gray')

print('Mode Warna : ',image_size200.mode)
print('Ukuran Gambar : ',image_size200.size)

pixel_image = np.array(image_size200)
print('Nilai Pixel dari gambar grayscale : ')
print(pixel_image)
# Out:
# Mode Warna :  L
# Ukuran Gambar :  (200, 200)
# Nilai Pixel dari gambar grayscale :
# [[21 21 21 ... 22 22 22]
#  [21 21 21 ... 22 22 22]
#  [21 21 21 ... 22 22 22]
#  ...
#  [21 21 21 ... 21 21 21]
#  [21 21 21 ... 21 21 21]
#  [21 21 21 ... 21 21 21]]
